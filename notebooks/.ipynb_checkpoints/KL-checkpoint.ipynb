# %%
import jax
import tensorflow_probability.substrates.jax as tfp
import matplotlib.pyplot as plt
import jax.numpy as jnp
import numpy as np
import pandas as pd

# %%
tfd = tfp.distributions

# %%
theta_p = 0.6
theta_q = 0.7
p = tfd.Bernoulli(probs=theta_p)
q = tfd.Bernoulli(probs=theta_q)

# %% [markdown]
# #### Using TFP

# %%
tfd.kl_divergence(q, p)
# Out:
# DeviceArray(0.02160087, dtype=float32)

# %% [markdown]
# #### Using derived formula

# %%
(1 - theta_q) * jnp.log((1 - theta_q) / (1 - theta_p)) + theta_q * jnp.log(
    (theta_q / theta_p)
)
# Out:
# DeviceArray(0.02160083, dtype=float32, weak_type=True)

# %% [markdown]
# #### using Monte Carlo

# %%
n_samples = 2000
q_samples = q.sample(sample_shape=(n_samples,), seed=jax.random.PRNGKey(1))

# %%
q_samples.sum()
# Out:
# DeviceArray(1391, dtype=int32)

# %%
jnp.log(q.prob(q_samples) / p.prob(q_samples)).mean()
# Out:
# DeviceArray(0.01961261, dtype=float32)

# %%
estimate = {}
for n_samples in np.power(10, jnp.array([0, 1, 2, 3, 4, 5, 6])):
    q_samples = q.sample(sample_shape=(n_samples,), seed=jax.random.PRNGKey(n_samples))
    estimate[n_samples] = jnp.log(q.prob(q_samples) / p.prob(q_samples)).mean().item()

# %%
pd.Series(estimate).plot(logx=True)
plt.axhline(tfd.kl_divergence(q, p), color="k")

# %% [markdown]
# #### Plotting $D_{KL}(q||p)$ as a function of $\theta_q$

# %%
theta_q_range = jnp.linspace(0.01, 0.99, 100)

# %%
plt.plot(theta_q_range, tfd.kl_divergence(tfd.Bernoulli(probs=theta_q_range), p))
plt.axvline(p.probs, color="k")

# %%
plt.plot(theta_q_range, tfd.kl_divergence(p, tfd.Bernoulli(probs=theta_q_range)))
plt.axvline(p.probs, color="k")

# %%
def loss(tq):
    return tfd.kl_divergence(tfd.Bernoulli(probs=tq), p)

# %%
p
# Out:
# <tfp.distributions.Bernoulli 'Bernoulli' batch_shape=[] event_shape=[] dtype=int32>

# %%
def f(x):
    return 3 * x**2

# %%
jax.grad(f)(0.2)
# Out:
# DeviceArray(1.2, dtype=float32, weak_type=True)

# %%
jax.grad(lambda a: tfd.kl_divergence(tfd.Bernoulli(probs=a), tfd.Bernoulli(probs=0.5)))(
    0.4
)
# Out:
# DeviceArray(-0.405465, dtype=float32, weak_type=True)

# %%
jax.grad(loss)(jnp.array(0.5))
# Out:
# DeviceArray(-0.40546513, dtype=float32, weak_type=True)

# %%
tq = 0.1
lr = 0.01
for i in range(201):
    l, delta = jax.value_and_grad(loss)(tq)
    tq = tq - lr * delta
    if i % 10 == 0:
        print(i, l, tq)
# Out:
# 0 0.5506613 0.1260269
# 10 0.20074165 0.29996455
# 20 0.08575225 0.40268296
# 30 0.037646174 0.46942008
# 40 0.016559541 0.5136463
# 50 0.0072478354 0.54303366
# 60 0.0031528473 0.562515
# 70 0.0013641417 0.57538563
# 80 0.000587821 0.58386236
# 90 0.00025257468 0.58943164
# 100 0.00010827184 0.5930842
# 110 4.6372414e-05 0.59547675
# 120 1.9907951e-05 0.5970426
# 130 8.493662e-06 0.59806687
# 140 3.5762787e-06 0.5987365
# 150 1.5795231e-06 0.5991743
# 160 7.748604e-07 0.5994604
# 170 3.2782555e-07 0.59964734
# 180 1.4901161e-07 0.59976953
# 190 8.940697e-08 0.59984946
# 200 2.9802322e-08 0.59990174

# %%
p_mix = tfd.MixtureSameFamily(
    mixture_distribution=tfd.Categorical(probs=[0.3, 0.7]),
    components_distribution=tfd.Normal(
        loc=[-1.0, 1], scale=[0.1, 0.5]  # One for each component.
    ),
)

# %%
x_lims = jnp.linspace(-5, 5, 1000)
plt.plot(x_lims, p_mix.prob(x_lims))

# %%
def loss_2(mean, logscale):
    norm = tfd.Normal(loc = mean, scale=jnp.exp(logscale))
    return tfd.kl_divergence(norm, p_mix)

# %%
l, delta = jax.value_and_grad(loss_2)(0.0, 1.)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 l, delta = jax.value_and_grad(loss_2)(0.0, 1.)
#
#     [... skipping hidden 8 frame]
#
# Input In [23], in loss_2(mean, logscale)
#       1 def loss_2(mean, logscale):
#       2     norm = tfd.Normal(loc = mean, scale=jnp.exp(logscale))
# ----> 3     return tfd.kl_divergence(norm, p_mix)
#
# File ~/miniconda3/lib/python3.9/site-packages/tensorflow_probability/substrates/jax/distributions/kullback_leibler.py:89, in kl_divergence(distribution_a, distribution_b, allow_nan_stats, name)
#      87 kl_fn = _registered_kl(distribution_a.__class__, distribution_b.__class__)
#      88 if kl_fn is None:
# ---> 89   raise NotImplementedError(
#      90       "No KL(distribution_a || distribution_b) registered for distribution_a "
#      91       "type {} and distribution_b type {}".format(
#      92           distribution_a.__class__.__name__,
#      93           distribution_b.__class__.__name__))
#      95 name = name or "KullbackLeibler"
#      96 with tf.name_scope(name):
#      97   # pylint: disable=protected-access
#
# NotImplementedError: No KL(distribution_a || distribution_b) registered for distribution_a type Normal and distribution_b type MixtureSameFamily

# %%
def loss_3(mean, logscale):
    n_samples = 1000
    q = tfd.Normal(loc = mean, scale=jnp.exp(logscale))
    q_samples = q.sample(sample_shape=(n_samples,), seed=jax.random.PRNGKey(1))
    l = jnp.log(q.prob(q_samples) / p_mix.prob(q_samples)).mean().item()
    return l

# %%
l, delta = jax.value_and_grad(loss_3)(0.0,1.0)
# Out:
# ---------------------------------------------------------------------------
# ConcretizationTypeError                   Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 l, delta = jax.value_and_grad(loss_3)(0.0,1.0)
#
#     [... skipping hidden 8 frame]
#
# Input In [25], in loss_3(mean, logscale)
#       3 q = tfd.Normal(loc = mean, scale=jnp.exp(logscale))
#       4 q_samples = q.sample(sample_shape=(n_samples,), seed=jax.random.PRNGKey(1))
# ----> 5 l = jnp.log(q.prob(q_samples) / p_mix.prob(q_samples)).mean().item()
#       6 return l
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/device_array.py:225, in item(self)
#     223   return complex(self)
#     224 elif dtypes.issubdtype(self.dtype, np.floating):
# --> 225   return float(self)
#     226 elif dtypes.issubdtype(self.dtype, np.integer):
#     227   return int(self)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/core.py:1177, in concretization_function_error.<locals>.error(self, arg)
#    1176 def error(self, arg):
# -> 1177   raise ConcretizationTypeError(arg, fname_context)
#
# ConcretizationTypeError: Abstract tracer value encountered where concrete value is expected: Traced<ConcreteArray(inf, dtype=float32)>with<JVPTrace(level=2/0)> with
#   primal = DeviceArray(inf, dtype=float32)
#   tangent = Traced<ShapedArray(float32[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float32[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x1aaafb8a0>, in_tracers=(Traced<ConcreteArray(1000.0, dtype=float32):JaxprTrace(level=1/0)>, Traced<ShapedArray(float32[1000]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x1aaaa7130; to 'JaxprTracer' at 0x1aaaa7360>], out_avals=[ShapedArray(float32[])], primitive=xla_call, params={'device': None, 'backend': None, 'name': '_mean', 'donated_invars': (False, False), 'inline': True, 'keep_unused': False, 'call_jaxpr': { lambda ; a:f32[] b:f32[1000]. let
#     c:f32[] = xla_call[
#       call_jaxpr={ lambda ; d:f32[1000]. let
#           e:f32[] = reduce_sum[axes=(0,)] d
#         in (e,) }
#       name=_reduce_sum
#     ] b
#     f:f32[] = div c a
#   in (f,) }}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x1aaaf6030>, name_stack=NameStack(stack=(Transform(name='jvp'),))))
# The problem arose with the `float` function. If trying to convert the data type of a value, try using `x.astype(float)` or `jnp.array(x, float)` instead.
#
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.ConcretizationTypeError

# %%
def loss_4(mean, logscale):
    n_samples = 500
    q_std  = tfd.Normal(loc = 0.0, scale = 1.0)
    q_std_samples = q_std.sample(sample_shape=(n_samples,), seed=jax.random.PRNGKey(1))
    q = tfd.Normal(loc = mean, scale = jnp.exp(logscale))
    q_samples = q_std_samples*jnp.exp(logscale) + mean

    return (q.log_prob(q_samples) - p_mix.log_prob(q_samples)).mean()

# %%
loss_4(0.0, 1.0)
# Out:
# DeviceArray(14.290649, dtype=float32)

# %%
jax.grad(loss_4)(0.0,1.0)
# Out:
# DeviceArray(-5.46795, dtype=float32, weak_type=True)

# %%
l, delta = jax.value_and_grad(loss_4, argnums=[0, 1])(0.0, 1.0, )

# %%
delta
# Out:
# (DeviceArray(-5.46795, dtype=float32, weak_type=True),
#  DeviceArray(30.25537, dtype=float32, weak_type=True))

# %%
q = tfd.Normal(loc = 0.0, scale=jnp.exp(1.0))

# %%
q_m = 0.0
q_ls = 1.0
lr = 0.01
for i in range(201):
    l, delta = jax.value_and_grad(loss_4, argnums=[0, 1])(q_m, q_ls)
    q_m = q_m - lr*delta[0]
    q_ls = q_ls - lr*delta[1]
    if i % 10 == 0:
        print(i, l, q_m, q_ls)
# Out:
# 0 14.290649 0.054679498 0.69744635
# 10 1.6220635 0.302801 0.03058676
# 20 1.052919 0.45081452 -0.1279525
# 30 0.7995833 0.57655704 -0.22604983
# 40 0.56601995 0.6959009 -0.3190738
# 50 0.44989082 0.78023344 -0.37353045
# 60 0.4125636 0.83291095 -0.39952612
# 70 0.3982366 0.86648333 -0.41300088
# 80 0.3914938 0.889741 -0.42296633
# 90 0.38771224 0.9065758 -0.43168965
# 100 0.38553175 0.91881734 -0.4393742
# 110 0.38406047 0.92819995 -0.44685495
# 120 0.38273397 0.9361948 -0.45517364
# 130 0.3811357 0.9439368 -0.46531558
# 140 0.37907392 0.9518237 -0.4774208
# 150 0.37682605 0.9593667 -0.49038184
# 160 0.37462515 0.9662921 -0.50347275
# 170 0.37252435 0.972629 -0.51648563
# 180 0.37047064 0.97856075 -0.52951795
# 190 0.36849588 0.9840814 -0.5424112
# 200 0.36658308 0.9892948 -0.5552157

# %%
q_learnt = tfd.Normal(loc = q_m, scale = jnp.exp(q_ls))

# %%
x_lims = jnp.linspace(-5, 5, 1000)
plt.plot(x_lims, p_mix.prob(x_lims))
plt.plot(x_lims, q_learnt.prob(x_lims))

# %%
def loss_5(mean, logscale):
    """
    D_KL(p||q) instead of D_KL(q||p)
    """
    n_samples = 500
    p_samples = p_mix.sample(sample_shape=(n_samples,), seed=jax.random.PRNGKey(1))
    q = tfd.Normal(loc = mean, scale = jnp.exp(logscale))

    return (-q.log_prob(p_samples) + p_mix.log_prob(p_samples)).mean()

# %%
loss_5(0.0,1.0)
# Out:
# DeviceArray(1.2390168, dtype=float32)

# %%
q_m = 0.0
q_ls = 1.0
lr = 0.01
for i in range(201):
    l, delta = jax.value_and_grad(loss_5, argnums=[0, 1])(q_m, q_ls)
    q_m = q_m - lr*delta[0]
    q_ls = q_ls - lr*delta[1]
    if i % 10 == 0:
        print(i, l, q_m, q_ls)
# Out:
# 0 1.2390168 0.00041360612 0.9915098
# 10 1.1688479 0.0049195024 0.90806854
# 20 1.1033401 0.0101451045 0.82753223
# 30 1.0428717 0.016151346 0.75026226
# 40 0.9877438 0.022985991 0.67661554
# 50 0.9381552 0.030677697 0.6069286
# 60 0.8941779 0.03923041 0.5414998
# 70 0.85574716 0.048618857 0.480572
# 80 0.8226596 0.058786154 0.42431733
# 90 0.79458815 0.069644056 0.37282628
# 100 0.77110595 0.081076205 0.32610196
# 110 0.7517195 0.09294418 0.28406152
# 120 0.735904 0.105095536 0.24654317
# 130 0.7231352 0.117372826 0.21331836
# 140 0.71291685 0.1296224 0.18410702
# 150 0.70479727 0.14170197 0.15859388
# 160 0.69838065 0.15348627 0.13644451
# 170 0.6933294 0.16487075 0.11731922
# 180 0.68936276 0.17577296 0.10088466
# 190 0.68625164 0.18613239 0.08682256
# 200 0.6838116 0.19590873 0.07483571

# %%
q_learnt_forward = tfd.Normal(loc = q_m, scale = jnp.exp(q_ls))

# %%
x_lims = jnp.linspace(-5, 5, 1000)
plt.plot(x_lims, p_mix.prob(x_lims), label='p (target)')
plt.plot(x_lims, q_learnt.prob(x_lims), label='q (Reverse mode KL min)')
plt.plot(x_lims, q_learnt_forward.prob(x_lims), label='q (Forward mode KL min)')
plt.legend()
